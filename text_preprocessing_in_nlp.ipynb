# %% [markdown]
# <a href="https://colab.research.google.com/github/bhoomikasuvarna/AI-and-ML/blob/main/text_preprocessing_in_nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install contractions
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 6.4 MB/s eta 0:00:00
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.0.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.0.0 textsearch-0.0.24

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.8.0

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
import pandas as pd
import contractions
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
nltk.download('averaged_perceptron_tagger')
import emoji
# pip install emoji
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_text_data(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)

    # Select the relevant column
    ds = df.iloc[:, [1]]
    ds

    # Convert emojis to text
    ds['emoji_text'] = ds['comment_text'].apply(lambda x: emoji.demojize(x))


      # Remove digits
    ds['remove_digits'] = ds["emoji_text"].replace(to_replace=r'\d', value='', regex=True)


    # Convert to lowercase
    ds = ds.applymap(lambda x: x.lower() if isinstance(x, str) else x)

      # Appcontracotionly contractions
    ds["contraction"] = ds["remove_digits"].apply(lambda x: contractions.fix(str(x)))

    ds['url_remove'] = ds["contraction"].apply(lambda x: re.sub(r'http\S+', '', str(x)))


    # Remove non-word and non-whitespace characters
    ds["whitespace"] = ds["url_remove"].replace(to_replace=r'[^\w\s]', value='', regex=True)


    # Tokenization
    ds['Tokenized_Comment'] = ds['whitespace'].apply(lambda x: word_tokenize(str(x)))

# #     # Stopword Removal
    stop_words = set(stopwords.words('english'))
    ds['stopword_Comment'] = ds['Tokenized_Comment'].apply(lambda x: [word for word in x if word not in stop_words])

# #     # Stemming
    stemmer = PorterStemmer()
    ds['stemmed_Comment'] = ds['stopword_Comment'].apply(lambda x: [stemmer.stem(word) for word in x])

# #     # Lemmatization
    lemmatizer = WordNetLemmatizer()
    def lemmatize_tokens(tokens):
        def get_wordnet_pos(word):
            tag = nltk.pos_tag([word])[0][1][0].upper()
            tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
            return tag_dict.get(tag, wordnet.NOUN)
        return [lemmatizer.lemmatize(token, get_wordnet_pos(token)) for token in tokens]
    ds['lemmatized_Comment'] = ds['stopword_Comment'].apply(lemmatize_tokens)

    return ds

processed_data = preprocess_text_data("/content/Call Me by Your Name (1).csv")
processed_data
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# <ipython-input-9-db613d8433ca>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds['emoji_text'] = ds['comment_text'].apply(lambda x: emoji.demojize(x))
# <ipython-input-9-db613d8433ca>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds['remove_digits'] = ds["emoji_text"].replace(to_replace=r'\d', value='', regex=True)
#                                           comment_text  \
# 0                                   gays? ag man @tsek
# 1    i 2 havent cried watching this movie so much; ...
# 2                       trash! pedophile perv garbage!
# 3    https://www.kaggle.com/datasets/promptcloudhq/...
# 4    yay for pedophilia! you go liberals! youre' aw...
# ..                                                 ...
# 975                                     wtf\n.........
# 976                                              song?
# 977                       yasssssssssss love  story!!!
# 978                                                  👎
# 979                       yaas fits like and commented
#
#                                             emoji_text  \
# 0                                   gays? ag man @tsek
# 1    i 2 havent cried watching this movie so much; ...
# 2                       trash! pedophile perv garbage!
# 3    https://www.kaggle.com/datasets/promptcloudhq/...
# 4    yay for pedophilia! you go liberals! youre' aw...
# ..                                                 ...
# 975                                     wtf\n.........
# 976                                              song?
# 977                       yasssssssssss love  story!!!
# 978                                      :thumbs_down:
# 979                       yaas fits like and commented
#
#                                          remove_digits  \
# 0                                   gays? ag man @tsek
# 1    i  havent cried watching this movie so much; c...
# 2                       trash! pedophile perv garbage!
# 3    https://www.kaggle.com/datasets/promptcloudhq/...
# 4    yay for pedophilia! you go liberals! youre' aw...
# ..                                                 ...
# 975                                     wtf\n.........
# 976                                              song?
# 977                       yasssssssssss love  story!!!
# 978                                      :thumbs_down:
# 979                       yaas fits like and commented
#
#                                            contraction  \
# 0                                   gays? ag man @tsek
# 1    i  have not cried watching this movie so much;...
# 2                       trash! pedophile perv garbage!
# 3    https://www.kaggle.com/datasets/promptcloudhq/...
# 4    yay for pedophilia! you go liberals! you are' ...
# ..                                                 ...
# 975                                     wtf\n.........
# 976                                              song?
# 977                       yasssssssssss love  story!!!
# 978                                      :thumbs_down:
# 979                       yaas fits like and commented
#
#                                             url_remove  \
# 0                                   gays? ag man @tsek
# 1    i  have not cried watching this movie so much;...
# 2                       trash! pedophile perv garbage!
# 3     i just watched at work lol and omg!! is a mas...
# 4    yay for pedophilia! you go liberals! you are' ...
# ..                                                 ...
# 975                                     wtf\n.........
# 976                                              song?
# 977                       yasssssssssss love  story!!!
# 978                                      :thumbs_down:
# 979                       yaas fits like and commented
#
#                                             whitespace  \
# 0                                     gays ag man tsek
# 1    i  have not cried watching this movie so much ...
# 2                         trash pedophile perv garbage
# 3     i just watched at work lol and omg is a maste...
# 4    yay for pedophilia you go liberals you are awe...
# ..                                                 ...
# 975                                              wtf\n
# 976                                               song
# 977                          yasssssssssss love  story
# 978                                        thumbs_down
# 979                       yaas fits like and commented
#
#                                      Tokenized_Comment  \
# 0                                [gays, ag, man, tsek]
# 1    [i, have, not, cried, watching, this, movie, s...
# 2                    [trash, pedophile, perv, garbage]
# 3    [i, just, watched, at, work, lol, and, omg, is...
# 4    [yay, for, pedophilia, you, go, liberals, you,...
# ..                                                 ...
# 975                                              [wtf]
# 976                                             [song]
# 977                       [yasssssssssss, love, story]
# 978                                      [thumbs_down]
# 979                 [yaas, fits, like, and, commented]
#
#                                       stopword_Comment  \
# 0                                [gays, ag, man, tsek]
# 1    [cried, watching, movie, much, cried, laughed,...
# 2                    [trash, pedophile, perv, garbage]
# 3    [watched, work, lol, omg, master, piece, words...
# 4             [yay, pedophilia, go, liberals, awesome]
# ..                                                 ...
# 975                                              [wtf]
# 976                                             [song]
# 977                       [yasssssssssss, love, story]
# 978                                      [thumbs_down]
# 979                      [yaas, fits, like, commented]
#
#                                        stemmed_Comment  \
# 0                                 [gay, ag, man, tsek]
# 1    [cri, watch, movi, much, cri, laugh, feel, gre...
# 2                      [trash, pedophil, perv, garbag]
# 3    [watch, work, lol, omg, master, piec, word, de...
# 4                 [yay, pedophilia, go, liber, awesom]
# ..                                                 ...
# 975                                              [wtf]
# 976                                             [song]
# 977                       [yasssssssssss, love, stori]
# 978                                      [thumbs_down]
# 979                          [yaa, fit, like, comment]
#
#                                     lemmatized_Comment
# 0                                 [gay, ag, man, tsek]
# 1    [cry, watch, movie, much, cry, laugh, feel, gr...
# 2                    [trash, pedophile, perv, garbage]
# 3    [watch, work, lol, omg, master, piece, word, d...
# 4              [yay, pedophilia, go, liberal, awesome]
# ..                                                 ...
# 975                                              [wtf]
# 976                                             [song]
# 977                       [yasssssssssss, love, story]
# 978                                      [thumbs_down]
# 979                         [yaas, fit, like, comment]
#
# [980 rows x 10 columns]
